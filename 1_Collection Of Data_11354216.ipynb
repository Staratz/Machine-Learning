# %% [markdown]
# # 1. Collection of Twitter Data

# %% [markdown]
# In order to gather data for analysis, the official Twitter API (https://developer.twitter.com) was utilised in combination with the package Tweepy (http://docs.tweepy.org/en/latest/). Due to the limitations of the API, tweets from 13 - 22 May were scraped on a daily basis. Each scape attempt was saved in a .csv file labelled 'dayofscraping_disney_tweets_total.csv'.

# %%
import tweepy
import csv

# %%
# API Keys and Authentification
consumer_key = 'G3T5MaLu5Ci9D6vNA4Ak2T4ka'
consumer_secret = 'tlogxZIjcel8yQmTfe4zUf1YMwqVFYRbTruYsjGo6F0GwAO6XV'
access_token = '810071767062560768-HWsA4EpBjxys8b6lh8JHpDGpK7EU3VM'
access_token_secret = 'c6pk9kOR6kqz9anpakvNSXOYf4a3R4w4jBX1KbnfYuQSL'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)
print(api.me().name) #test if API is functional
# Out:
# Alexander M. Atzberger

# %% [markdown]
# Tweet Scraper on all tweets with the hashtag #Disney which scraped all daily tweets in English excluding all retweets. The process was repeated daily, in this case the 22 May and gathered in corresponding .csv files.

# %%
csvFile = open('22_disney_tweets_total.csv', 'a') #saving as CSV locally
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q="#disney" + '-filter:retweets', 
                           lang="en",
                           since="2020-05-22", until="2020-05-23").items(1600):
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# 2020-05-22 23:59:41 Today's blog post is all about my tattoos and the meaning behind them! Check it out!
# https://t.co/1anbAk2pR2… https://t.co/WFVHIQ3la0
# 2020-05-22 23:58:59 What will happen if Deadpool wants some lightsaber with disney getting all the license it open doors!! #DarthVader… https://t.co/wgc4dH4GkI
# 2020-05-22 23:58:33 its Disney?who is he?
# #Disney
# 2020-05-22 23:55:53 Redemption - Chapter 08
# -
# #starwars #disney #mandalorian #chapter08 #redemption #mando #jedi #baby #yoda #child… https://t.co/UdNOewF7Kd
# 2020-05-22 23:55:45 Time for tonight's Be Our Guest Podcast Community Check-in!  Show starts at the top of the hour and we are LIVE NOW… https://t.co/oqckFWRMnA
# 2020-05-22 23:55:02 Take An At Home Disney Photo Shoot With These Adorable Cameras: https://t.co/UIiNkGLOIt
#
# #Disney #DisneyPhotos… https://t.co/LVKe1bH7Hj
# ...
